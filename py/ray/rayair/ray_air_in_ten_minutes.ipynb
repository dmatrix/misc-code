# %% [markdown]
# ## A gentle 10-minute introduction to Ray AI Runitime (Ray AIR)
#
# As part of Ray 2.0, Ray AI Runtime (AIR) is an open-source toolkit for building end-to-end ML applications. By leveraging Ray, its distributed compute capabilities, and its library ecosystem, Ray AIR brings scalability and programmability to ML platforms.
#
# Ray AI Runtime focuses on two functional aspects:
#  * It provides scalability by leveraging Ray’s distributed compute layer for ML workloads.
#  * It is designed to interoperate with other systems for storage and metadata needs.
#
# Ray AIR consists of five key Ray components:
#
#  * Data processing ([Ray Data](https://docs.ray.io/en/latest/data/dataset.html))
#  * Model Training ([Ray Train](https://docs.ray.io/en/latest/train/train.html))
#  * Reinforcement Learning ([Ray RLlib](https://docs.ray.io/en/latest/rllib/index.html))
#  * Hyperparameter Tuning ([Ray Tune](https://docs.ray.io/en/latest/tune/index.html))
#  * Model Serving ([Ray Serve](https://docs.ray.io/en/latest/serve/index.html)).
#
#  <img src = "images/ai_runtime.jpeg" width="60%" height="30%">
#
# ### Learning objectives:
#   * Get introduced to Ray AIR as a unified toolkit to write an end-to-end ML application in a single Python script
#   * Get exposed to Ray data for data ingestion
#   * Learn about out-of-box Preprocessors
#   * Load model from checkpoint and use for batch inference
#   * Learn to deploy model and use for online inference

# %%
import logging, os, random, warnings
from pprint import pprint
import ray
import pandas as pd
from sklearn.model_selection import train_test_split

from ray.data.preprocessors import StandardScaler

# %%
warnings.filterwarnings("ignore")
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
if ray.is_initialized:
    ray.shutdown()
context = ray.init(logging_level=logging.ERROR)
pprint(context)
# Out:
# RayContext(dashboard_url='127.0.0.1:8266', python_version='3.8.13', ray_version='3.0.0.dev0', ray_commit='{{RAY_COMMIT_SHA}}', address_info={'node_ip_address': '127.0.0.1', 'raylet_ip_address': '127.0.0.1', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2022-07-20_09-59-17_235461_30511/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-07-20_09-59-17_235461_30511/sockets/raylet', 'webui_url': '127.0.0.1:8266', 'session_dir': '/tmp/ray/session_2022-07-20_09-59-17_235461_30511', 'metrics_export_port': 64493, 'gcs_address': '127.0.0.1:62846', 'address': '127.0.0.1:62846', 'dashboard_agent_listen_port': 52365, 'node_id': '77b154b5e9078df027f0fcfb0cb5db7cd3b472867f54b9d847eaf155'})

# %%
print(f"Dashboard url: http://{context.address_info['webui_url']}")
# Out:
# Dashboard url: http://127.0.0.1:8266

# %% [markdown]
# ### Create Ray data from an S3 CSV datasource

# %%
import ray
import pandas as pd
from ray.air import train_test_split

# Split data into train and validation.
dataset = ray.data.read_csv("s3://anonymous@air-example-data/breast_cancer.csv")
train_dataset, valid_dataset = train_test_split(dataset, test_size=0.3)
test_dataset = valid_dataset.drop_columns(["target"])
# Out:
# Map_Batches: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 76.46it/s]

# %% [markdown]
# ### Create Preprocessors
# This preprocessor is automatically used in the training function to `fit` and `tranform` your datasets for training and validation.

# %%
# Create a preprocessor to scale some columns
from ray.data.preprocessors import StandardScaler

columns_to_scale = ["mean radius", "mean texture"]
preprocessor = StandardScaler(columns=columns_to_scale)

# %% [markdown]
# ### Create Trainers
# Use the Ray AIR trainer `XGBoostTrainer`. Simple steps:
#  1. define the parallelism for Ray compute
#  2. define the XGBoost parameters for training
#  3. supply the preprocessor for fitting and transforming dataset during training and validation
#  4. provide the datasets training and validation
#  5. invoke `trainer.fit()`
#
#  Simple API that does a lot behind the scenes!

# %%
from ray.train.xgboost import XGBoostTrainer

trainer = XGBoostTrainer(
    scaling_config={
        # Number of workers to use for data parallelism.
        "num_workers": 2,
        # Whether to use GPU acceleration.
        "use_gpu": False,
    },
    label_column="target",
    num_boost_round=20,
    params={
        # XGBoost specific params
        "objective": "binary:logistic",
        "eval_metric": ["logloss", "error"],
    },
    datasets={"train": train_dataset, "valid": valid_dataset},
    preprocessor=preprocessor,
)
result = trainer.fit()
print(result.metrics)
# Out:
# == Status ==<br>Current time: 2022-07-20 10:08:21 (running for 00:00:07.45)<br>Memory usage on this node: 17.0/64.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/10 CPUs, 0/0 GPUs, 0.0/43.87 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /Users/jules/ray_results/XGBoostTrainer_2022-07-20_10-08-13<br>Number of trials: 1/1 (1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                </th><th>status    </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train-logloss</th><th style="text-align: right;">  train-error</th><th style="text-align: right;">  valid-logloss</th></tr>
# </thead>
# <tbody>
# <tr><td>XGBoostTrainer_89eea_00000</td><td>TERMINATED</td><td>127.0.0.1:32882</td><td style="text-align: right;">    20</td><td style="text-align: right;">         4.51621</td><td style="text-align: right;">      0.0184957</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.0893879</td></tr>
# </tbody>
# </table><br><br>
# (_map_block_nosplit pid=32033) E0720 10:08:13.821844000 6132838400 chttp2_transport.cc:1111]          Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (XGBoostTrainer pid=32882) 2022-07-20 10:08:15,980	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=32882) 2022-07-20 10:08:17,540	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (_RemoteRayXGBoostActor pid=32894) 2022-07-20 10:08:18,521	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=32894)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=32894)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=32894)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=32894)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=32894)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=32894)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=32894)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=32894)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=32894)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=32894)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=32894)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=32894)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=32894)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=32894)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=32894)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=32894)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=32895) 2022-07-20 10:08:18,589	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=32895)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=32895)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=32895)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=32895)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=32895)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=32895)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=32895)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=32895)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=32895)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=32895)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=32895)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=32895)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=32895)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=32895)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=32895)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=32895)     traceback.print_stack()
# (XGBoostTrainer pid=32882) 2022-07-20 10:08:18,704	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=32894) [10:08:18] task [xgboost.ray]:4795309168 got new rank 0
# (_RemoteRayXGBoostActor pid=32895) [10:08:18] task [xgboost.ray]:5533375600 got new rank 1
# Result for XGBoostTrainer_89eea_00000:
#   date: 2022-07-20_10-08-20
#   done: false
#   experiment_id: 8a44aa699d134bbca129d68b4e4f7ae6
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 32882
#   should_checkpoint: true
#   time_since_restore: 4.391774892807007
#   time_this_iter_s: 4.391774892807007
#   time_total_s: 4.391774892807007
#   timestamp: 1658336900
#   timesteps_since_restore: 0
#   train-error: 0.02261306532663317
#   train-logloss: 0.464117960489575
#   training_iteration: 1
#   trial_id: 89eea_00000
#   valid-error: 0.11695906432748537
#   valid-logloss: 0.5025240946234318
#   warmup_time: 0.0025348663330078125
# (XGBoostTrainer pid=32882) 2022-07-20 10:08:20,500	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 2.97 seconds (1.79 pure XGBoost training time).
# Result for XGBoostTrainer_89eea_00000:
#   date: 2022-07-20_10-08-20
#   done: true
#   experiment_id: 8a44aa699d134bbca129d68b4e4f7ae6
#   experiment_tag: '0'
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 32882
#   should_checkpoint: true
#   time_since_restore: 4.51620888710022
#   time_this_iter_s: 0.0064239501953125
#   time_total_s: 4.51620888710022
#   timestamp: 1658336900
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.01849572773292735
#   training_iteration: 20
#   trial_id: 89eea_00000
#   valid-error: 0.04093567251461988
#   valid-logloss: 0.08938791319913073
#   warmup_time: 0.0025348663330078125
#
# {'train-logloss': 0.01849572773292735, 'train-error': 0.0, 'valid-logloss': 0.08938791319913073, 'valid-error': 0.04093567251461988, 'time_this_iter_s': 0.0064239501953125, 'should_checkpoint': True, 'done': True, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 20, 'trial_id': '89eea_00000', 'experiment_id': '8a44aa699d134bbca129d68b4e4f7ae6', 'date': '2022-07-20_10-08-20', 'timestamp': 1658336900, 'time_total_s': 4.51620888710022, 'pid': 32882, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {}, 'time_since_restore': 4.51620888710022, 'timesteps_since_restore': 0, 'iterations_since_restore': 20, 'warmup_time': 0.0025348663330078125, 'experiment_tag': '0'}

# %% [markdown]
# ### Create Tuner for hyperparameter search
#
# What if you want to do some hyperparameter optimization during training and use the best config for the model?
# Well, you can then use Tuner and supply your training function as part of the argument, along with other Tuner
# configuration.
#
# Again, simple steps:
#  1. define your hyperparameter space
#  2. define `TuneConfig` for number of trials and parallelism
#  3. invoke `tuner.fit()`

# %%
from ray import tune

param_space = {"params": {"max_depth": tune.randint(1, 9)}}
metric = "train-logloss"

# %%
from ray.tune.tuner import Tuner, TuneConfig
from ray.air.config import RunConfig

tuner = Tuner(
    trainer,
    param_space=param_space,
    tune_config=TuneConfig(num_samples=5, metric=metric, mode="min"),
)
# Execute tuning.
result_grid = tuner.fit()

# Fetch the best result.That is its best hyperparameter config
best_result = result_grid.get_best_result()
print("Best Result:", best_result)
# Out:
# == Status ==<br>Current time: 2022-07-20 10:13:56 (running for 00:00:12.95)<br>Memory usage on this node: 16.3/64.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/10 CPUs, 0/0 GPUs, 0.0/43.87 GiB heap, 0.0/2.0 GiB objects<br>Current best trial: 4ec83_00000 with train-logloss=0.01841634292981527 and parameters={'params': {'max_depth': 5}}<br>Result logdir: /Users/jules/ray_results/XGBoostTrainer_2022-07-20_10-13-43<br>Number of trials: 5/5 (5 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                </th><th>status    </th><th>loc            </th><th style="text-align: right;">  params/max_depth</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  train-logloss</th><th style="text-align: right;">  train-error</th><th style="text-align: right;">  valid-logloss</th></tr>
# </thead>
# <tbody>
# <tr><td>XGBoostTrainer_4ec83_00000</td><td>TERMINATED</td><td>127.0.0.1:33502</td><td style="text-align: right;">                 5</td><td style="text-align: right;">    20</td><td style="text-align: right;">         4.61511</td><td style="text-align: right;">      0.0184163</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.105782 </td></tr>
# <tr><td>XGBoostTrainer_4ec83_00001</td><td>TERMINATED</td><td>127.0.0.1:33506</td><td style="text-align: right;">                 3</td><td style="text-align: right;">    20</td><td style="text-align: right;">         3.43237</td><td style="text-align: right;">      0.0215151</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.0765915</td></tr>
# <tr><td>XGBoostTrainer_4ec83_00002</td><td>TERMINATED</td><td>127.0.0.1:33507</td><td style="text-align: right;">                 5</td><td style="text-align: right;">    20</td><td style="text-align: right;">         3.7597 </td><td style="text-align: right;">      0.0184163</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.105782 </td></tr>
# <tr><td>XGBoostTrainer_4ec83_00003</td><td>TERMINATED</td><td>127.0.0.1:33566</td><td style="text-align: right;">                 3</td><td style="text-align: right;">    20</td><td style="text-align: right;">         4.62312</td><td style="text-align: right;">      0.0215151</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.0765915</td></tr>
# <tr><td>XGBoostTrainer_4ec83_00004</td><td>TERMINATED</td><td>127.0.0.1:33570</td><td style="text-align: right;">                 5</td><td style="text-align: right;">    20</td><td style="text-align: right;">         4.04092</td><td style="text-align: right;">      0.0184163</td><td style="text-align: right;">            0</td><td style="text-align: right;">      0.105782 </td></tr>
# </tbody>
# </table><br><br>
# (_block_to_df pid=32889) E0720 10:13:44.790356000 6199128064 chttp2_transport.cc:1111]          Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (XGBoostTrainer pid=33502) 2022-07-20 10:13:44,785	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=33502) 2022-07-20 10:13:45,902	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (XGBoostTrainer pid=33506) 2022-07-20 10:13:45,918	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=33506) 2022-07-20 10:13:45,983	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (XGBoostTrainer pid=33507) 2022-07-20 10:13:45,982	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=33507) 2022-07-20 10:13:46,137	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (_block_to_df pid=32886) E0720 10:13:47.036719000 6200471552 chttp2_transport.cc:1111]          Received a GOAWAY with error code ENHANCE_YOUR_CALM and debug data equal to "too_many_pings"
# (_RemoteRayXGBoostActor pid=33515) 2022-07-20 10:13:47,235	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=33515)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=33515)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=33515)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=33515)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=33515)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=33515)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=33515)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=33515)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=33515)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=33515)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=33515)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=33515)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=33515)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=33515)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=33515)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=33515)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=33514) 2022-07-20 10:13:47,203	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=33514)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=33514)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=33514)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=33514)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=33514)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=33514)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=33514)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=33514)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=33514)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=33514)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=33514)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=33514)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=33514)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=33514)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=33514)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=33514)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=33523) 2022-07-20 10:13:47,259	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=33523)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=33523)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=33523)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=33523)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=33523)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=33523)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=33523)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=33523)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=33523)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=33523)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=33523)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=33523)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=33523)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=33523)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=33523)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=33523)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=33522) 2022-07-20 10:13:47,250	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=33522)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=33522)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=33522)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=33522)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=33522)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=33522)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=33522)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=33522)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=33522)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=33522)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=33522)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=33522)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=33522)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=33522)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=33522)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=33522)     traceback.print_stack()
# (XGBoostTrainer pid=33502) 2022-07-20 10:13:47,355	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (XGBoostTrainer pid=33506) 2022-07-20 10:13:47,378	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=33515) [10:13:47] task [xgboost.ray]:4982426880 got new rank 1
# (_RemoteRayXGBoostActor pid=33514) [10:13:47] task [xgboost.ray]:4864420832 got new rank 0
# (_RemoteRayXGBoostActor pid=33523) [10:13:47] task [xgboost.ray]:4804336704 got new rank 1
# (_RemoteRayXGBoostActor pid=33522) [10:13:47] task [xgboost.ray]:5297282160 got new rank 0
# (_RemoteRayXGBoostActor pid=33542) 2022-07-20 10:13:47,713	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=33542)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=33542)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=33542)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=33542)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=33542)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=33542)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=33542)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=33542)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=33542)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=33542)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=33542)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=33542)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=33542)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=33542)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=33542)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=33542)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=33543) 2022-07-20 10:13:47,723	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=33543)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=33543)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=33543)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=33543)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=33543)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=33543)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=33543)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=33543)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=33543)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=33543)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=33543)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=33543)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=33543)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=33543)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=33543)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=33543)     traceback.print_stack()
# (XGBoostTrainer pid=33507) 2022-07-20 10:13:47,840	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=33542) [10:13:47] task [xgboost.ray]:4816780208 got new rank 0
# (_RemoteRayXGBoostActor pid=33543) [10:13:47] task [xgboost.ray]:6009642144 got new rank 1
# Result for XGBoostTrainer_4ec83_00001:
#   date: 2022-07-20_10-13-49
#   done: false
#   experiment_id: ab445a1094b043e795d8d51ba583c4e0
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 33506
#   should_checkpoint: true
#   time_since_restore: 3.255877733230591
#   time_this_iter_s: 3.255877733230591
#   time_total_s: 3.255877733230591
#   timestamp: 1658337229
#   timesteps_since_restore: 0
#   train-error: 0.03517587939698492
#   train-logloss: 0.47431553248784053
#   training_iteration: 1
#   trial_id: 4ec83_00001
#   valid-error: 0.09941520467836257
#   valid-logloss: 0.5004687657830311
#   warmup_time: 0.002753019332885742
#
# Result for XGBoostTrainer_4ec83_00000:
#   date: 2022-07-20_10-13-49
#   done: false
#   experiment_id: 68acc7455e6240d1a27e911f52c4a1f3
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 33502
#   should_checkpoint: true
#   time_since_restore: 4.445180892944336
#   time_this_iter_s: 4.445180892944336
#   time_total_s: 4.445180892944336
#   timestamp: 1658337229
#   timesteps_since_restore: 0
#   train-error: 0.02261306532663317
#   train-logloss: 0.465611254524945
#   training_iteration: 1
#   trial_id: 4ec83_00000
#   valid-error: 0.0935672514619883
#   valid-logloss: 0.5058815336366843
#   warmup_time: 0.002573728561401367
# (XGBoostTrainer pid=33506) 2022-07-20 10:13:49,358	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 3.39 seconds (1.97 pure XGBoost training time).
# (XGBoostTrainer pid=33502) 2022-07-20 10:13:49,406	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 3.52 seconds (2.05 pure XGBoost training time).
# Result for XGBoostTrainer_4ec83_00000:
#   date: 2022-07-20_10-13-49
#   done: true
#   experiment_id: 68acc7455e6240d1a27e911f52c4a1f3
#   experiment_tag: 0_max_depth=5
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 33502
#   should_checkpoint: true
#   time_since_restore: 4.615113973617554
#   time_this_iter_s: 0.008207082748413086
#   time_total_s: 4.615113973617554
#   timestamp: 1658337229
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.01841634292981527
#   training_iteration: 20
#   trial_id: 4ec83_00000
#   valid-error: 0.05263157894736842
#   valid-logloss: 0.10578184703239703
#   warmup_time: 0.002573728561401367
#
# Result for XGBoostTrainer_4ec83_00002:
#   date: 2022-07-20_10-13-49
#   done: false
#   experiment_id: dfd4553c9c414a6ab9b6fa38ba5f2ed9
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 33507
#   should_checkpoint: true
#   time_since_restore: 3.637022018432617
#   time_this_iter_s: 3.637022018432617
#   time_total_s: 3.637022018432617
#   timestamp: 1658337229
#   timesteps_since_restore: 0
#   train-error: 0.02261306532663317
#   train-logloss: 0.465611254524945
#   training_iteration: 1
#   trial_id: 4ec83_00002
#   valid-error: 0.0935672514619883
#   valid-logloss: 0.5058815336366843
#   warmup_time: 0.003317117691040039
#
# Result for XGBoostTrainer_4ec83_00001:
#   date: 2022-07-20_10-13-49
#   done: true
#   experiment_id: ab445a1094b043e795d8d51ba583c4e0
#   experiment_tag: 1_max_depth=3
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 33506
#   should_checkpoint: true
#   time_since_restore: 3.4323678016662598
#   time_this_iter_s: 0.010448932647705078
#   time_total_s: 3.4323678016662598
#   timestamp: 1658337229
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.02151511543566108
#   training_iteration: 20
#   trial_id: 4ec83_00001
#   valid-error: 0.03508771929824561
#   valid-logloss: 0.07659151291540056
#   warmup_time: 0.002753019332885742
# (XGBoostTrainer pid=33507) 2022-07-20 10:13:49,745	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 3.64 seconds (1.90 pure XGBoost training time).
# Result for XGBoostTrainer_4ec83_00002:
#   date: 2022-07-20_10-13-49
#   done: true
#   experiment_id: dfd4553c9c414a6ab9b6fa38ba5f2ed9
#   experiment_tag: 2_max_depth=5
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 33507
#   should_checkpoint: true
#   time_since_restore: 3.7597010135650635
#   time_this_iter_s: 0.0060307979583740234
#   time_total_s: 3.7597010135650635
#   timestamp: 1658337229
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.01841634292981527
#   training_iteration: 20
#   trial_id: 4ec83_00002
#   valid-error: 0.05263157894736842
#   valid-logloss: 0.10578184703239703
#   warmup_time: 0.003317117691040039
# (XGBoostTrainer pid=33566) 2022-07-20 10:13:51,203	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=33570) 2022-07-20 10:13:51,533	WARNING base_trainer.py:162 -- When passing `datasets` to a Trainer, it is recommended to reserve at least 20% of node CPUs for Dataset execution by setting `_max_cpu_fraction_per_node = 0.8` in the Trainer `scaling_config`. Not doing so can lead to resource contention or hangs. See https://docs.ray.io/en/master/data/key-concepts.html#example-datasets-in-tune for more info.
# (XGBoostTrainer pid=33570) 2022-07-20 10:13:52,406	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (XGBoostTrainer pid=33566) 2022-07-20 10:13:52,855	INFO main.py:980 -- [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (_RemoteRayXGBoostActor pid=33585) 2022-07-20 10:13:53,452	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=33585)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=33585)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=33585)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=33585)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=33585)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=33585)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=33585)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=33585)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=33585)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=33585)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=33585)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=33585)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=33585)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=33585)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=33585)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=33585)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=33584) 2022-07-20 10:13:53,496	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=33584)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=33584)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=33584)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=33584)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=33584)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=33584)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=33584)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=33584)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=33584)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=33584)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=33584)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=33584)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=33584)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=33584)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=33584)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=33584)     traceback.print_stack()
# (XGBoostTrainer pid=33570) 2022-07-20 10:13:53,611	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=33585) [10:13:53] task [xgboost.ray]:5402385520 got new rank 1
# (_RemoteRayXGBoostActor pid=33584) [10:13:53] task [xgboost.ray]:4907474080 got new rank 0
# (_RemoteRayXGBoostActor pid=33597) 2022-07-20 10:13:53,922	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=33597)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=33597)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=33597)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=33597)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=33597)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=33597)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=33597)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=33597)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=33597)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=33597)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=33597)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=33597)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=33597)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=33597)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=33597)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=33597)     traceback.print_stack()
# (_RemoteRayXGBoostActor pid=33596) 2022-07-20 10:13:53,922	WARNING __init__.py:192 -- DeprecationWarning: `ray.worker.get_resource_ids` is a private attribute and access will be removed in a future Ray version.
# (_RemoteRayXGBoostActor pid=33596)   File "/Users/jules/git-repos/ray/python/ray/_private/workers/default_worker.py", line 237, in <module>
# (_RemoteRayXGBoostActor pid=33596)     ray._private.worker.global_worker.main_loop()
# (_RemoteRayXGBoostActor pid=33596)   File "/Users/jules/git-repos/ray/python/ray/_private/worker.py", line 754, in main_loop
# (_RemoteRayXGBoostActor pid=33596)     self.core_worker.run_task_loop()
# (_RemoteRayXGBoostActor pid=33596)   File "/Users/jules/git-repos/ray/python/ray/_private/function_manager.py", line 674, in actor_method_executor
# (_RemoteRayXGBoostActor pid=33596)     return method(__ray_actor, *args, **kwargs)
# (_RemoteRayXGBoostActor pid=33596)   File "/Users/jules/git-repos/ray/python/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (_RemoteRayXGBoostActor pid=33596)     return method(self, *_args, **_kwargs)
# (_RemoteRayXGBoostActor pid=33596)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 474, in __init__
# (_RemoteRayXGBoostActor pid=33596)     _set_omp_num_threads()
# (_RemoteRayXGBoostActor pid=33596)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 280, in _set_omp_num_threads
# (_RemoteRayXGBoostActor pid=33596)     ray_cpus = _ray_get_actor_cpus()
# (_RemoteRayXGBoostActor pid=33596)   File "/opt/miniconda3/envs/ray-build/lib/python3.8/site-packages/xgboost_ray/main.py", line 262, in _ray_get_actor_cpus
# (_RemoteRayXGBoostActor pid=33596)     resource_ids = ray.worker.get_resource_ids()
# (_RemoteRayXGBoostActor pid=33596)   File "/Users/jules/git-repos/ray/python/ray/__init__.py", line 196, in __getattr__
# (_RemoteRayXGBoostActor pid=33596)     traceback.print_stack()
# (XGBoostTrainer pid=33566) 2022-07-20 10:13:54,040	INFO main.py:1025 -- [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=33597) [10:13:54] task [xgboost.ray]:5035547712 got new rank 1
# (_RemoteRayXGBoostActor pid=33596) [10:13:54] task [xgboost.ray]:5106683184 got new rank 0
# Result for XGBoostTrainer_4ec83_00004:
#   date: 2022-07-20_10-13-55
#   done: false
#   experiment_id: 817793337ab145c1a2864b6c606638ff
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 33570
#   should_checkpoint: true
#   time_since_restore: 3.8910109996795654
#   time_this_iter_s: 3.8910109996795654
#   time_total_s: 3.8910109996795654
#   timestamp: 1658337235
#   timesteps_since_restore: 0
#   train-error: 0.02261306532663317
#   train-logloss: 0.465611254524945
#   training_iteration: 1
#   trial_id: 4ec83_00004
#   valid-error: 0.0935672514619883
#   valid-logloss: 0.5058815336366843
#   warmup_time: 0.002708911895751953
# (XGBoostTrainer pid=33570) 2022-07-20 10:13:55,578	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 3.18 seconds (1.96 pure XGBoost training time).
# Result for XGBoostTrainer_4ec83_00003:
#   date: 2022-07-20_10-13-55
#   done: false
#   experiment_id: ce8d9fe83d284ad2aec1013b7d8a2d6c
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 1
#   node_ip: 127.0.0.1
#   pid: 33566
#   should_checkpoint: true
#   time_since_restore: 4.509383916854858
#   time_this_iter_s: 4.509383916854858
#   time_total_s: 4.509383916854858
#   timestamp: 1658337235
#   timesteps_since_restore: 0
#   train-error: 0.03517587939698492
#   train-logloss: 0.47431553248784053
#   training_iteration: 1
#   trial_id: 4ec83_00003
#   valid-error: 0.09941520467836257
#   valid-logloss: 0.5004687657830311
#   warmup_time: 0.0027549266815185547
# (XGBoostTrainer pid=33566) 2022-07-20 10:13:55,830	INFO main.py:1516 -- [RayXGBoost] Finished XGBoost training on training data with total N=398 in 2.99 seconds (1.79 pure XGBoost training time).
# Result for XGBoostTrainer_4ec83_00004:
#   date: 2022-07-20_10-13-55
#   done: true
#   experiment_id: 817793337ab145c1a2864b6c606638ff
#   experiment_tag: 4_max_depth=5
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 33570
#   should_checkpoint: true
#   time_since_restore: 4.04092001914978
#   time_this_iter_s: 0.005606174468994141
#   time_total_s: 4.04092001914978
#   timestamp: 1658337235
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.01841634292981527
#   training_iteration: 20
#   trial_id: 4ec83_00004
#   valid-error: 0.05263157894736842
#   valid-logloss: 0.10578184703239703
#   warmup_time: 0.002708911895751953
#
# Result for XGBoostTrainer_4ec83_00003:
#   date: 2022-07-20_10-13-55
#   done: true
#   experiment_id: ce8d9fe83d284ad2aec1013b7d8a2d6c
#   experiment_tag: 3_max_depth=3
#   hostname: Juless-MacBook-Pro-16
#   iterations_since_restore: 20
#   node_ip: 127.0.0.1
#   pid: 33566
#   should_checkpoint: true
#   time_since_restore: 4.623118162155151
#   time_this_iter_s: 0.005937337875366211
#   time_total_s: 4.623118162155151
#   timestamp: 1658337235
#   timesteps_since_restore: 0
#   train-error: 0.0
#   train-logloss: 0.02151511543566108
#   training_iteration: 20
#   trial_id: 4ec83_00003
#   valid-error: 0.03508771929824561
#   valid-logloss: 0.07659151291540056
#   warmup_time: 0.0027549266815185547
#
# Best Result: Result(metrics={'train-logloss': 0.01841634292981527, 'train-error': 0.0, 'valid-logloss': 0.10578184703239703, 'valid-error': 0.05263157894736842, 'time_this_iter_s': 0.008207082748413086, 'should_checkpoint': True, 'done': True, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 20, 'trial_id': '4ec83_00000', 'experiment_id': '68acc7455e6240d1a27e911f52c4a1f3', 'date': '2022-07-20_10-13-49', 'timestamp': 1658337229, 'time_total_s': 4.615113973617554, 'pid': 33502, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 4.615113973617554, 'timesteps_since_restore': 0, 'iterations_since_restore': 20, 'warmup_time': 0.002573728561401367, 'experiment_tag': '0_max_depth=5'}, checkpoint=<ray.air.checkpoint.Checkpoint object at 0x129b0cf40>, error=None, log_dir=PosixPath('/Users/jules/ray_results/XGBoostTrainer_2022-07-20_10-13-43/XGBoostTrainer_4ec83_00000_0_max_depth=5_2022-07-20_10-13-43'), metrics_dataframe=    train-logloss  train-error  valid-logloss  valid-error  time_this_iter_s  \
# 0        0.465611     0.022613       0.505882     0.093567          4.445181
# 1        0.332896     0.010050       0.386077     0.052632          0.010396
# 2        0.252007     0.012563       0.326293     0.076023          0.008340
# 3        0.191715     0.010050       0.267602     0.058480          0.008387
# 4        0.149730     0.007538       0.226837     0.052632          0.008483
# 5        0.119332     0.007538       0.198947     0.046784          0.008371
# 6        0.096740     0.005025       0.175565     0.052632          0.008352
# 7        0.078592     0.002513       0.163899     0.052632          0.008399
# 8        0.065687     0.002513       0.155128     0.052632          0.009819
# 9        0.055314     0.002513       0.146913     0.052632          0.009142
# 10       0.047350     0.002513       0.136977     0.052632          0.009989
# 11       0.041698     0.002513       0.133636     0.052632          0.010632
# 12       0.036109     0.002513       0.124063     0.052632          0.009114
# 13       0.032127     0.002513       0.120173     0.052632          0.010428
# 14       0.028889     0.002513       0.116081     0.058480          0.010857
# 15       0.026126     0.000000       0.111825     0.052632          0.007219
# 16       0.023875     0.000000       0.114316     0.058480          0.007469
# 17       0.021785     0.000000       0.112586     0.052632          0.008359
# 18       0.019855     0.000000       0.107597     0.052632          0.007970
# 19       0.018416     0.000000       0.105782     0.052632          0.008207
#
#     should_checkpoint   done  timesteps_total  episodes_total  \
# 0                True  False              NaN             NaN
# 1                True  False              NaN             NaN
# 2                True  False              NaN             NaN
# 3                True  False              NaN             NaN
# 4                True  False              NaN             NaN
# 5                True  False              NaN             NaN
# 6                True  False              NaN             NaN
# 7                True  False              NaN             NaN
# 8                True  False              NaN             NaN
# 9                True  False              NaN             NaN
# 10               True  False              NaN             NaN
# 11               True  False              NaN             NaN
# 12               True  False              NaN             NaN
# 13               True  False              NaN             NaN
# 14               True  False              NaN             NaN
# 15               True  False              NaN             NaN
# 16               True  False              NaN             NaN
# 17               True  False              NaN             NaN
# 18               True  False              NaN             NaN
# 19               True  False              NaN             NaN
#
#     training_iteration  ...                 date   timestamp time_total_s  \
# 0                    1  ...  2022-07-20_10-13-49  1658337229     4.445181
# 1                    2  ...  2022-07-20_10-13-49  1658337229     4.455577
# 2                    3  ...  2022-07-20_10-13-49  1658337229     4.463917
# 3                    4  ...  2022-07-20_10-13-49  1658337229     4.472304
# 4                    5  ...  2022-07-20_10-13-49  1658337229     4.480787
# 5                    6  ...  2022-07-20_10-13-49  1658337229     4.489158
# 6                    7  ...  2022-07-20_10-13-49  1658337229     4.497510
# 7                    8  ...  2022-07-20_10-13-49  1658337229     4.505909
# 8                    9  ...  2022-07-20_10-13-49  1658337229     4.515728
# 9                   10  ...  2022-07-20_10-13-49  1658337229     4.524870
# 10                  11  ...  2022-07-20_10-13-49  1658337229     4.534859
# 11                  12  ...  2022-07-20_10-13-49  1658337229     4.545491
# 12                  13  ...  2022-07-20_10-13-49  1658337229     4.554605
# 13                  14  ...  2022-07-20_10-13-49  1658337229     4.565033
# 14                  15  ...  2022-07-20_10-13-49  1658337229     4.575890
# 15                  16  ...  2022-07-20_10-13-49  1658337229     4.583109
# 16                  17  ...  2022-07-20_10-13-49  1658337229     4.590578
# 17                  18  ...  2022-07-20_10-13-49  1658337229     4.598937
# 18                  19  ...  2022-07-20_10-13-49  1658337229     4.606907
# 19                  20  ...  2022-07-20_10-13-49  1658337229     4.615114
#
#       pid               hostname    node_ip time_since_restore  \
# 0   33502  Juless-MacBook-Pro-16  127.0.0.1           4.445181
# 1   33502  Juless-MacBook-Pro-16  127.0.0.1           4.455577
# 2   33502  Juless-MacBook-Pro-16  127.0.0.1           4.463917
# 3   33502  Juless-MacBook-Pro-16  127.0.0.1           4.472304
# 4   33502  Juless-MacBook-Pro-16  127.0.0.1           4.480787
# 5   33502  Juless-MacBook-Pro-16  127.0.0.1           4.489158
# 6   33502  Juless-MacBook-Pro-16  127.0.0.1           4.497510
# 7   33502  Juless-MacBook-Pro-16  127.0.0.1           4.505909
# 8   33502  Juless-MacBook-Pro-16  127.0.0.1           4.515728
# 9   33502  Juless-MacBook-Pro-16  127.0.0.1           4.524870
# 10  33502  Juless-MacBook-Pro-16  127.0.0.1           4.534859
# 11  33502  Juless-MacBook-Pro-16  127.0.0.1           4.545491
# 12  33502  Juless-MacBook-Pro-16  127.0.0.1           4.554605
# 13  33502  Juless-MacBook-Pro-16  127.0.0.1           4.565033
# 14  33502  Juless-MacBook-Pro-16  127.0.0.1           4.575890
# 15  33502  Juless-MacBook-Pro-16  127.0.0.1           4.583109
# 16  33502  Juless-MacBook-Pro-16  127.0.0.1           4.590578
# 17  33502  Juless-MacBook-Pro-16  127.0.0.1           4.598937
# 18  33502  Juless-MacBook-Pro-16  127.0.0.1           4.606907
# 19  33502  Juless-MacBook-Pro-16  127.0.0.1           4.615114
#
#    timesteps_since_restore  iterations_since_restore  warmup_time
# 0                        0                         1     0.002574
# 1                        0                         2     0.002574
# 2                        0                         3     0.002574
# 3                        0                         4     0.002574
# 4                        0                         5     0.002574
# 5                        0                         6     0.002574
# 6                        0                         7     0.002574
# 7                        0                         8     0.002574
# 8                        0                         9     0.002574
# 9                        0                        10     0.002574
# 10                       0                        11     0.002574
# 11                       0                        12     0.002574
# 12                       0                        13     0.002574
# 13                       0                        14     0.002574
# 14                       0                        15     0.002574
# 15                       0                        16     0.002574
# 16                       0                        17     0.002574
# 17                       0                        18     0.002574
# 18                       0                        19     0.002574
# 19                       0                        20     0.002574
#
# [20 rows x 22 columns], best_checkpoints=[(<ray.air.checkpoint.Checkpoint object at 0x12f55ebb0>, {'train-logloss': 0.465611254524945, 'train-error': 0.02261306532663317, 'valid-logloss': 0.5058815336366843, 'valid-error': 0.0935672514619883, 'time_this_iter_s': 4.445180892944336, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 1, 'trial_id': '4ec83_00000', 'experiment_id': '68acc7455e6240d1a27e911f52c4a1f3', 'date': '2022-07-20_10-13-49', 'timestamp': 1658337229, 'time_total_s': 4.445180892944336, 'pid': 33502, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 4.445180892944336, 'timesteps_since_restore': 0, 'iterations_since_restore': 1, 'warmup_time': 0.002573728561401367, 'experiment_tag': '0_max_depth=5'}), (<ray.air.checkpoint.Checkpoint object at 0x12f580d60>, {'train-logloss': 0.33289550244808197, 'train-error': 0.01005025125628141, 'valid-logloss': 0.3860774944748795, 'valid-error': 0.05263157894736842, 'time_this_iter_s': 0.010396003723144531, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 2, 'trial_id': '4ec83_00000', 'experiment_id': '68acc7455e6240d1a27e911f52c4a1f3', 'date': '2022-07-20_10-13-49', 'timestamp': 1658337229, 'time_total_s': 4.4555768966674805, 'pid': 33502, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 4.4555768966674805, 'timesteps_since_restore': 0, 'iterations_since_restore': 2, 'warmup_time': 0.002573728561401367, 'experiment_tag': '0_max_depth=5'}), (<ray.air.checkpoint.Checkpoint object at 0x12f5800a0>, {'train-logloss': 0.2520069157583031, 'train-error': 0.01256281407035176, 'valid-logloss': 0.3262928800973279, 'valid-error': 0.07602339181286549, 'time_this_iter_s': 0.008339881896972656, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 3, 'trial_id': '4ec83_00000', 'experiment_id': '68acc7455e6240d1a27e911f52c4a1f3', 'date': '2022-07-20_10-13-49', 'timestamp': 1658337229, 'time_total_s': 4.463916778564453, 'pid': 33502, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 4.463916778564453, 'timesteps_since_restore': 0, 'iterations_since_restore': 3, 'warmup_time': 0.002573728561401367, 'experiment_tag': '0_max_depth=5'}), (<ray.air.checkpoint.Checkpoint object at 0x12f580e50>, {'train-logloss': 0.19171511336936423, 'train-error': 0.01005025125628141, 'valid-logloss': 0.26760199273887436, 'valid-error': 0.05847953216374269, 'time_this_iter_s': 0.008387088775634766, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 4, 'trial_id': '4ec83_00000', 'experiment_id': '68acc7455e6240d1a27e911f52c4a1f3', 'date': '2022-07-20_10-13-49', 'timestamp': 1658337229, 'time_total_s': 4.472303867340088, 'pid': 33502, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_restore': 4.472303867340088, 'timesteps_since_restore': 0, 'iterations_since_restore': 4, 'warmup_time': 0.002573728561401367, 'experiment_tag': '0_max_depth=5'}), (<ray.air.checkpoint.Checkpoint object at 0x12f580b50>, {'train-logloss': 0.14972986310870204, 'train-error': 0.00753768844221105, 'valid-logloss': 0.22683743971307374, 'valid-error': 0.05263157894736842, 'time_this_iter_s': 0.008483171463012695, 'should_checkpoint': True, 'done': False, 'timesteps_total': None, 'episodes_total': None, 'training_iteration': 5, 'trial_id': '4ec83_00000', 'experiment_id': '68acc7455e6240d1a27e911f52c4a1f3', 'date': '2022-07-20_10-13-49', 'timestamp': 1658337229, 'time_total_s': 4.480787038803101, 'pid': 33502, 'hostname': 'Juless-MacBook-Pro-16', 'node_ip': '127.0.0.1', 'config': {'params': {'max_depth': 5}}, 'time_since_resto ...

# %% [markdown]
# ### Create a `BatchPreditor` for batch prediction
# Once you have trained and tuned your model, create a batch predictor from best model using the `best_result.checkpoint` and do batch inference.

# %%
from ray.train.batch_predictor import BatchPredictor
from ray.train.xgboost import XGBoostPredictor

batch_predictor = BatchPredictor.from_checkpoint(best_result.checkpoint, XGBoostPredictor)

predicted_probabilities = batch_predictor.predict(test_dataset)
print("PREDICTED PROBABILITIES")
predicted_probabilities.show()
# Out:
# Map Progress (1 actors 1 pending): 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.37it/s]
# PREDICTED PROBABILITIES
# {'predictions': 0.9960426092147827}
# {'predictions': 0.9957077503204346}
# {'predictions': 0.0034389763604849577}
# {'predictions': 0.9962536096572876}
# {'predictions': 0.9968380928039551}
# {'predictions': 0.9957551956176758}
# {'predictions': 0.9920042157173157}
# {'predictions': 0.994161069393158}
# {'predictions': 0.2891101539134979}
# {'predictions': 0.974367082118988}
# {'predictions': 0.0034389763604849577}
# {'predictions': 0.9959942102432251}
# {'predictions': 0.9474029541015625}
# {'predictions': 0.9923243522644043}
# {'predictions': 0.9941523671150208}
# {'predictions': 0.1239369809627533}
# {'predictions': 0.5043733716011047}
# {'predictions': 0.9935414791107178}
# {'predictions': 0.9832899570465088}
# {'predictions': 0.0034389763604849577}

# %% [markdown]
# ### Create `PredictorDeployment` for Online Inference
# Deploy the best model as an inference service by using Ray Serve and the `PredictorDeployment` class.

# %%
from ray import serve
from fastapi import Request
from ray.serve import PredictorDeployment
from ray.serve.http_adapters import json_request


async def adapter(request: Request):
    content = await request.json()
    print(content)
    return pd.DataFrame.from_dict(content)


serve.start(detached=True)
deployment = PredictorDeployment.options(name="XGBoostService")

deployment.deploy(
    XGBoostPredictor, best_result.checkpoint, batching_params=False, http_adapter=adapter
)

print(deployment.url)
# Out:
# (ServeController pid=34551) INFO 2022-07-20 10:24:02,391 controller 34551 checkpoint_path.py:17 - Using RayInternalKVStore for controller checkpoint and recovery.
# (ServeController pid=34551) INFO 2022-07-20 10:24:02,419 controller 34551 http_state.py:123 - Starting HTTP proxy with name 'SERVE_CONTROLLER_ACTOR:SERVE_PROXY_ACTOR-77b154b5e9078df027f0fcfb0cb5db7cd3b472867f54b9d847eaf155' on node '77b154b5e9078df027f0fcfb0cb5db7cd3b472867f54b9d847eaf155' listening on '127.0.0.1:8000'
# (HTTPProxyActor pid=34553) INFO:     Started server process [34553]
# (ServeController pid=34551) INFO 2022-07-20 10:24:03,041 controller 34551 deployment_state.py:1280 - Adding 1 replicas to deployment 'XGBoostService'.
# http://127.0.0.1:8000/XGBoostService

# %% [markdown]
# After deploying the service, you can send requests to it.

# %%
import requests

sample_input = test_dataset.take(1)
sample_input = dict(sample_input[0])

output = requests.post(deployment.url, json=[sample_input]).json()
print(output)
# Out:
# [{'predictions': 0.9960426092147827}]
# (ServeReplica:XGBoostService pid=34555) [{'mean radius': 11.06, 'mean texture': 14.83, 'mean perimeter': 70.31, 'mean area': 378.2, 'mean smoothness': 0.07741, 'mean compactness': 0.04768, 'mean concavity': 0.02712, 'mean concave points': 0.007246, 'mean symmetry': 0.1535, 'mean fractal dimension': 0.06214, 'radius error': 0.1855, 'texture error': 0.6881, 'perimeter error': 1.263, 'area error': 12.98, 'smoothness error': 0.004259, 'compactness error': 0.01469, 'concavity error': 0.0194, 'concave points error': 0.004168, 'symmetry error': 0.01191, 'fractal dimension error': 0.003537, 'worst radius': 12.68, 'worst texture': 20.35, 'worst perimeter': 80.79, 'worst area': 496.7, 'worst smoothness': 0.112, 'worst compactness': 0.1879, 'worst concavity': 0.2079, 'worst concave points': 0.05556, 'worst symmetry': 0.259, 'worst fractal dimension': 0.09158}]
# (HTTPProxyActor pid=34553) INFO 2022-07-20 10:24:15,872 http_proxy 127.0.0.1 http_proxy.py:315 - POST /XGBoostService 307 5.7ms
# (HTTPProxyActor pid=34553) INFO 2022-07-20 10:24:15,880 http_proxy 127.0.0.1 http_proxy.py:315 - POST /XGBoostService 200 6.3ms
# (ServeReplica:XGBoostService pid=34555) INFO 2022-07-20 10:24:15,871 XGBoostService XGBoostService#LVqWvb replica.py:478 - HANDLE __call__ OK 0.3ms
# (ServeReplica:XGBoostService pid=34555) INFO 2022-07-20 10:24:15,879 XGBoostService XGBoostService#LVqWvb replica.py:478 - HANDLE __call__ OK 4.4ms

# %%
ray.shutdown()
