# %%
import pandas as pd
from utils import Utils

# %% [markdown]
# ### Read from the source: File

# %%
df = Utils.load_csv_data("../data/windfarm_data.csv")

# %%
df.head()
# Out:
#   year_month_day  temperature_00  wind_direction_00  wind_speed_00  \
# 0     2014-01-01        4.702022         106.742590       4.743292
# 1     2014-01-02        7.695733          98.036705       6.142715
# 2     2014-01-03        9.608235         274.061200      10.514304
# 3     2014-01-04        6.955563         257.910220       7.189170
# 4     2014-01-05        0.830547         265.394400       4.263086
#
#    temperature_08  wind_direction_08  wind_speed_08  temperature_16  \
# 0        7.189482          100.41638       6.593832        8.172301
# 1        9.977118           94.03181       4.383676        9.690135
# 2       10.840864          242.87563      16.869741        8.991079
# 3        5.317223          254.26170       9.069233        3.021174
# 4        2.480239          104.79496       3.042063        4.227131
#
#    wind_direction_16  wind_speed_16      power
# 0           99.28800       5.967206  1959.3535
# 1          204.25444       1.696528  1266.6239
# ...

# %% [markdown]
# ### Read from the Feast formated source: Delta Table

# %%
df = Utils.load_parquet_data("data/weather_forecast_features")

# %%
df.head()
# Out:
#   year_month_day  temperature_00  wind_direction_00  wind_speed_00  \
# 0     2014-01-01        4.702022         106.742590       4.743292
# 1     2014-01-02        7.695733          98.036705       6.142715
# 2     2014-01-03        9.608235         274.061200      10.514304
# 3     2014-01-04        6.955563         257.910220       7.189170
# 4     2014-01-05        0.830547         265.394400       4.263086
#
#    temperature_08  wind_direction_08  wind_speed_08  temperature_16  \
# 0        7.189482          100.41638       6.593832        8.172301
# 1        9.977118           94.03181       4.383676        9.690135
# 2       10.840864          242.87563      16.869741        8.991079
# 3        5.317223          254.26170       9.069233        3.021174
# 4        2.480239          104.79496       3.042063        4.227131
#
#    wind_direction_16  wind_speed_16      power            datetime  \
# 0           99.28800       5.967206  1959.3535 2014-01-01 08:00:00
# ...

# %%
list(df.year_month_day.unique())
# Out:
# ['2014-01-01',
#  '2014-01-02',
#  '2014-01-03',
#  '2014-01-04',
#  '2014-01-05',
#  '2014-01-06',
#  '2014-01-07',
#  '2014-01-08',
#  '2014-01-09',
#  '2014-01-10',
#  '2014-01-11',
#  '2014-01-12',
#  '2014-01-13',
#  '2014-01-14',
#  '2014-01-15',
#  '2014-01-16',
#  '2014-01-17',
#  '2014-01-18',
#  '2014-01-19',
#  '2014-01-20',
#  '2014-01-21',
#  '2014-01-22',
#  '2014-01-23',
#  '2014-01-24',
#  '2014-01-25',
#  '2014-01-26',
#  '2014-01-27',
#  '2014-01-28',
#  '2014-01-29',
#  '2014-01-30',
#  '2014-01-31',
#  '2014-02-01',
#  '2014-02-02',
#  '2014-02-03',
#  '2014-02-04',
#  '2014-02-05',
#  '2014-02-06',
#  '2014-02-07',
#  '2014-02-08',
#  '2014-02-09',
#  '2014-02-10',
#  '2014-02-11',
#  '2014-02-12',
#  '2014-02-13',
#  '2014-02-14',
#  '2014-02-15',
#  '2014-02-16',
#  '2014-02-17',
#  '2014-02-18',
#  '2014-02-19',
#  '2014-02-20',
#  '2014-02-21',
#  '2014-02-22',
#  '2014-02-23',
#  '2014-02-24',
#  '2014-02-25',
#  '2014-02-26',
#  '2014-02-27',
# ...
