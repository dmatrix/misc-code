# %%
import pandas as pd

# %%
path="/Users/julesdamji/examples/py/feature_store/feature_repo/data/driver_stats.parquet"
df = pd.read_parquet(path=path)
df.head(5)
# Out:
#                    datetime  driver_id  conv_rate  acc_rate  avg_daily_trips  \
# 0 2021-05-06 10:00:00+00:00       1005   0.999493  0.251107              761
# 1 2021-05-06 11:00:00+00:00       1005   0.077831  0.472850              906
# 2 2021-05-06 12:00:00+00:00       1005   0.193274  0.700155               41
# 3 2021-05-06 13:00:00+00:00       1005   0.302772  0.781375              374
# 4 2021-05-06 14:00:00+00:00       1005   0.239107  0.648385              602
#
#                   created
# 0 2021-05-21 10:52:52.668
# 1 2021-05-21 10:52:52.668
# 2 2021-05-21 10:52:52.668
# 3 2021-05-21 10:52:52.668
# 4 2021-05-21 10:52:52.668

# %%
wine_path = "/Users/julesdamji/examples/py/feature_store/data/wine_features.parquet"
wine_df = pd.read_parquet(wine_path)
wine_df.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...
